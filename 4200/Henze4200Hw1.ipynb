# %%
Bday = 24
d = 1 + (Bday % 2)
m = 2 + (Bday // 2)
print(Bday, d, m)
# Out:
# 24 1 14

# %%
x = int(input())
y = int(input())
# Out:
#  10
#  3

# %%
x + y
# Out:
# 13

# %%
x - y
# Out:
# 7

# %%
x * y
# Out:
# 30

# %%
x / y
# Out:
# 3.3333333333333335

# %%
x // y
# Out:
# 3

# %%
x ** y
# Out:
# 1000

# %%
x % y
# Out:
# 1

# %%
print("number \tsquare \tcube")
x = 2
print(x, '\t', x * x, '\t', x ** 3)
x = 4
print(x, '\t', x * x, '\t', x ** 3)
x = 6
print(x, '\t', x * x, '\t', x ** 3)
x = 8
print(x, '\t', x * x, '\t', x ** 3)
x = 10
print(x, '\t', x * x, '\t', x ** 3)
# Out:
# number 	square 	cube
# 2 	 4 	 8
# 4 	 16 	 64
# 6 	 36 	 216
# 8 	 64 	 512
# 10 	 100 	 1000
