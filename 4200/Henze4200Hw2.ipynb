# %%
Bday = 24
d = 1 + (Bday % 2)
m = 2 + (Bday // 2)

# %%
#Question 1
total = 0
numItems = 0
itemProfits = [200,150,240,108,55,56,48,34,124,210]
for item in itemProfits:
    total += item
    numItems += 1

averageProfit = total/numItems
print(averageProfit)
# Out:
# 122.5

# %% [markdown]
# Question 2 Included in seperate PDF

# %%
#Question 3
import random
numList = []
for i in range(1,(d*m)+1):
    numList.append(random.randint(1,100))

print(numList)
numList.sort()
print(numList)
numList.sort(reverse=True)
print(numList)

numList = list(set(numList))
numList.sort()
print(numList)
# Out:
# [91, 36, 19, 68, 38, 63, 78, 50, 80, 2, 23, 55, 91, 86]
# [2, 19, 23, 36, 38, 50, 55, 63, 68, 78, 80, 86, 91, 91]
# [91, 91, 86, 80, 78, 68, 63, 55, 50, 38, 36, 23, 19, 2]
# [2, 19, 23, 36, 38, 50, 55, 63, 68, 78, 80, 86, 91]

# %%
#Question 4
def square_cube(num):
    try:
        x = int(num)
        return x ** 2, x ** 3
    except:
        print("NOT AN INT")

# %%
getnum = input()
# Out:
#  3

# %%
print(square_cube(getnum))
# Out:
# (9, 27)

# %%
#Question 5
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns

# %%
rolls1 = [random.randrange(1,7) for x in range(10 * m)]
rolls2 = [random.randrange(1,7) for x in range(10 * m)]

values1, frequencies1 = np.unique(rolls1, return_counts=True)
values2, frequencies2 = np.unique(rolls2, return_counts=True)

totalvalues = values1
totalfrequencies = frequencies1 + frequencies2
print(totalvalues,totalfrequencies)
# Out:
# [1 2 3 4 5 6] [53 52 37 41 46 51]

# %%
title = f'Rolling Two 6 Sided Die {len(rolls1):,} Times'
sns.set_style('whitegrid')
axes = sns.barplot(x=totalvalues, y=totalfrequencies, palette='bright')

axes.set_title(title)
plt.Text(0.5,1,'XXXYYYZZZ')
axes.set(xlabel='Die Values', ylabel='Frequencies')
[plt.Text(92.667,0.5,'YYY'), plt.Text(0.5,58.7667,'XXX')]

axes.set_ylim(top=max(totalfrequencies) * 1.10)
for bar, frequency in zip(axes.patches, totalfrequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency / len(rolls1):.3%}'
    axes.text(text_x, text_y, text, fontsize=11, ha='center', va='bottom')
# Out:
# C:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
